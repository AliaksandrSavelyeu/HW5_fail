# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/vehicles_prep2.csv'

# %%
import pandas as pd
data = pd.read_csv(path)

# %%
data
# Out:
#         price    year manufacturer                     model  condition  \
# 0       33590  2014.0          gmc  sierra 1500 crew cab slt       good
# 1       22590  2010.0    chevrolet            silverado 1500       good
# 2       39590  2020.0    chevrolet       silverado 1500 crew       good
# 3       30990  2017.0       toyota      tundra double cab sr       good
# 4       15000  2013.0         ford                 f-150 xlt  excellent
# ...       ...     ...          ...                       ...        ...
# 396329  23590  2019.0       nissan         maxima s sedan 4d       good
# 396330  30590  2020.0        volvo  s60 t5 momentum sedan 4d       good
# 396331  34990  2020.0     cadillac          xt4 sport suv 4d       good
# 396332  28990  2018.0        lexus           es 350 sedan 4d       good
# 396333  30590  2019.0          bmw  4 series 430i gran coupe       good
#
#           cylinders    fuel  odometer transmission drive       type
# ...

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 9.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 72.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 5.1 MB/s eta 0:00:00
# ...

# %%
from pycaret.regression import *
s = setup(data, target = 'price', session_id = 123)
# Out:
# <style type="text/css">
# #T_16ac4_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_16ac4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16ac4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_16ac4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16ac4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16ac4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_16ac4_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_16ac4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16ac4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_16ac4_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_16ac4_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_e2ca9 th {
#   text-align: left;
# }
# ...
