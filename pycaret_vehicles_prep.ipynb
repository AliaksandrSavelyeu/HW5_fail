# %%
import pandas as pd
data = pd.read_csv('D:/Savelyeu/HW5/vehicles_prep.csv')

# %%
data
# Out:
#         region  price    year  manufacturer    model  condition  cylinders
# 0         16.0  33590  2014.0          14.0  17992.0        2.0        6.0  \
# 1         16.0  22590  2010.0           7.0  18387.0        2.0        6.0
# 2         16.0  39590  2020.0           7.0  18413.0        2.0        6.0
# 3         16.0  30990  2017.0          38.0  21224.0        2.0        6.0
# 4         16.0  15000  2013.0          13.0   9158.0        0.0        5.0
# ...        ...    ...     ...           ...      ...        ...        ...
# 396329   397.0  23590  2019.0          30.0  13907.0        2.0        5.0
# 396330   397.0  30590  2020.0          40.0  17383.0        2.0        5.0
# 396331   397.0  34990  2020.0           6.0  22583.0        2.0        5.0
# 396332   397.0  28990  2018.0          23.0   8184.0        2.0        5.0
# 396333   397.0  30590  2019.0           4.0   1753.0        2.0        5.0
#
# ...

# %%
from pycaret.regression import *
s = setup(data, target = 'price', session_id = 123)
# Out:
# <style type="text/css">
# #T_78edb_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_78edb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78edb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_78edb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78edb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78edb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_78edb_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_78edb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78edb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_78edb_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_78edb_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_d2206 th {
#   text-align: left;
# }
# ...
